# %%
import matplotlib.pyplot as plt
import numpy as np
from os import path
# %matplotlib inline

# %%
a_apnea = np.load(path.join("augmented_data", "augmented_SpO2_normal.npy")).flatten()
r_apnea = np.load(path.join("merged_data", "SpO2_apnea.npy")).flatten()

# %%
plt.figure(figsize=(20, 10))
plt.ylim(-0.1, 1.1)
plt.plot(a_apnea[:600000:])
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.ylim(-0.1, 1.1)
plt.plot(r_apnea[:600000:])
plt.show()
